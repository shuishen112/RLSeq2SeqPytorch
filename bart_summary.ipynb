# %%
from datasets import load_dataset
dataset = load_dataset("ccdv/cnn_dailymail",'3.0.0')
# Out:
# ...
#   0%|          | 0/5 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/159M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/376M [00:00<?, ?B/s]
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /projects/futhark1/data/wzm289/code/Text-Summarizer-Pytorch/bart_summary.ipynb Cell 1' in <cell line: 2>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/Text-Summarizer-Pytorch/bart_summary.ipynb#ch0000000vscode-remote?line=0'>1</a> from datasets import load_dataset
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bfutharkhpa01fl.unicph.domain/projects/futhark1/data/wzm289/code/Text-Summarizer-Pytorch/bart_summary.ipynb#ch0000000vscode-remote?line=1'>2</a> dataset = load_dataset("ccdv/cnn_dailymail",'3.0.0')
#
# ...
